# %%
import time
from functools import wraps


def trace(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        inicio = time.perf_counter()
        resultado = func(*args, **kwargs)
        fim = time.perf_counter()
        print(f"{func.__name__} executou em {(fim - inicio)*1000:.2f} ms")
        return resultado

    return wrapper


@trace
def calcular():
    sum(i * i for i in range(1_000_000))


calcular()
# Out:
# calcular executou em 307.51 ms
