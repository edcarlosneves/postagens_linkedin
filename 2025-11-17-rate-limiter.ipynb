# %%
import time


class RateLimiter:
    def __init__(self, rate, capacidade):
        self.rate = rate
        self.capacidade = capacidade
        self.tokens = capacidade
        self.ultimo_reabastecimento = time.time()

    def permitir(self):
        agora = time.time()
        delta = agora - self.ultimo_reabastecimento
        self.tokens = min(self.capacidade, self.tokens + delta * self.rate)
        self.ultimo_reabastecimento = agora

        if self.tokens >= 1:
            self.tokens -= 1
            return True
        return False


rate_limiter = RateLimiter(rate=1, capacidade=2)

for i in range(10):
    if bucket.permitir():
        print("Permitido:", i)
    else:
        print("Bloqueado:", i)
    time.sleep(0.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 26
#      23 rate_limiter = RateLimiter(rate=1, capacidade=2)
#      25 for i in range(10):
# ---> 26     if bucket.permitir():
#      27         print("Permitido:", i)
#      28     else:
#
# NameError: name 'bucket' is not defined
